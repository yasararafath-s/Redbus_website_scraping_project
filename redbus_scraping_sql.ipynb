# %% [markdown]
# ## Project: Redbus Data Scraping with Selenium & Dynamic Filtering using Streamlit

# %% [markdown]
# ### Web scraping using selenium

# %% [markdown]
# #### 1. Installed required packages

# %%
# pip install selenium
# pip install streamlit
# pip install pandas
# pip install mysql-connector-python
# pip install numpy

# %% [markdown]
# #### 2. Imported required packages

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver import ActionChains
from selenium.common.exceptions import TimeoutException, NoSuchElementException
import mysql.connector
import numpy as np
import os

# %% [markdown]
# #### 3. Extracting state bus links using selenium webdriver in edge browser

# %%
# setting up the driver
driver = webdriver.Edge()
driver.get('https://www.redbus.in')
driver.maximize_window()
time.sleep(0.5)

# finding the links from the source
redbus_links = driver.find_element(By.XPATH,"//*[@id='homeV2-root']/div[3]/div[1]/div[2]/a")
redbus_links.click()

# Wait for the new tab to open
time.sleep(0.5)

# Fetch the URL of the new tab
c_url = redbus_links.get_attribute('href')
driver.get(c_url)

# Extracting the links from the new tab
links=driver.find_elements(By.CLASS_NAME,'D113_link')
links_webs={}
for i in links:
    links_webs.update({i.text: i.get_attribute('href')})

# Close the browser
driver.quit()

links_webs

# %% [markdown]
# #### 4. Scraping all the states and storing the data in a csv file

# %%
# Initialize the Edge driver
driver = webdriver.Edge()

# Dictionary of state links
state_link_list = {
    'KSRTC (Kerala)': 'https://www.redbus.in/online-booking/ksrtc-kerala',
    'APSRTC': 'https://www.redbus.in/online-booking/apsrtc',
    'TSRTC': 'https://www.redbus.in/online-booking/tsrtc',
    'RSRTC': 'https://www.redbus.in/online-booking/rsrtc',
    'PePSU (Punjab)': 'https://www.redbus.in/online-booking/pepsu-punjab',
    'HRTC': 'https://www.redbus.in/online-booking/hrtc',
    'WBTC (CTC)': 'https://www.redbus.in/online-booking/wbtc-ctc',
    'ASTC': 'https://www.redbus.in/online-booking/astc',
    'KTCL': 'https://www.redbus.in/online-booking/ktcl',
    'BSRTC': 'https://www.redbus.in/online-booking/bihar-state-road-transport-corporation-bsrtc'
}

# Function to scrape route links and bus information for a specific state
def scrape_state_buses(state_name, state_url):
    # State bus data dictionary to store the scraped data
    state_dict = {
        "State": [], "Route_name": [], "Bus_name": [], "Bus_type": [], "Departure_time": [],
        "Duration": [], "Arrival_time": [], "Ratings": [], "Fare": [], "Seats_available": [], "Link": []
    }

    # Access the state buses page
    driver.get(state_url)
    time.sleep(0.5) 

    wait = WebDriverWait(driver, 20)
    state_links_list = []

    # Pagination to collect route links
    page_number = 1
    while True:
        try:
            # Collect all route links on the current page
            state_links = driver.find_elements(By.XPATH, '//a[@class="route"]')
            for route in state_links:
                state_links_list.append(route.get_attribute('href'))
                state_dict["Route_name"].append(route.text)
                state_dict["Link"].append(route.get_attribute('href'))

            # Try to click the next page button
            try:
                next_page_button = driver.find_element(By.XPATH, f"//div[contains(@class, 'DC_117_pageTabs') and text()='{page_number + 1}']")
                action = ActionChains(driver)
                action.move_to_element(next_page_button).perform()
                time.sleep(2)
                next_page_button.click()
                page_number += 1
                time.sleep(3)
            except NoSuchElementException:
                print(f"No more pages found for {state_name}.")
                break  # Exit the loop if no more pages are found
        except Exception as e:
            print(f"Error in scraping route links for {state_name}: {e}")
            break

    # Get unique route links
    state_unique_links = list(set(state_links_list))
    print(f"Number of unique routes for {state_name}: {len(state_unique_links)}")

    # Iterate through each unique route link to get bus details
    for route_link in state_unique_links:
        driver.get(route_link)
        time.sleep(3)

        # Try to click "View Buses" for additional buses (if available)
        try:
            view_buses_buttons = driver.find_elements(By.XPATH, '//div[@class="button"]')
            for button in reversed(view_buses_buttons):
                button.click()
                time.sleep(2)
        except:
            pass
        
        # Infinite scrolling to load all bus details on the page
        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(3)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        # Scrape bus data
        buses = driver.find_elements(By.XPATH, "//div[@class='clearfix bus-item-details']")
        State_route_name = driver.find_element(By.XPATH, '//h1[@class="D136_h1"]').text
        State_route_link = route_link

        for bus in buses:
            # Ensure that every key has a value even if it is missing
            state_dict['State'].append(state_name)
            state_dict['Route_name'].append(State_route_name)
            state_dict['Link'].append(State_route_link)

            try:
                state_dict['Bus_name'].append(bus.find_element(By.XPATH, ".//div[@class='travels lh-24 f-bold d-color']").text)
            except:
                state_dict['Bus_name'].append(None)

            try:
                state_dict['Bus_type'].append(bus.find_element(By.XPATH, ".//div[@class='bus-type f-12 m-top-16 l-color evBus']").text)
            except:
                state_dict['Bus_type'].append(None)

            try:
                state_dict['Departure_time'].append(bus.find_element(By.XPATH, ".//div[@class='dp-time f-19 d-color f-bold']").text)
            except:
                state_dict['Departure_time'].append(None)

            try:
                state_dict['Duration'].append(bus.find_element(By.XPATH, ".//div[@class='column-four p-right-10 w-10 fl']").text)
            except:
                state_dict['Duration'].append(None)

            try:
                state_dict['Arrival_time'].append(bus.find_element(By.XPATH, ".//div[@class='bp-time f-19 d-color disp-Inline']").text)
            except:
                state_dict['Arrival_time'].append(None)

            try:
                state_dict['Ratings'].append(float(bus.find_element(By.XPATH, ".//div[@class='rating-sec lh-24']").text))
            except:
                state_dict['Ratings'].append(0)

            try:
                state_dict['Fare'].append(bus.find_element(By.XPATH, ".//span[@class='f-19 f-bold']").text)
            except:
                state_dict['Fare'].append(0)

            try:
                state_dict['Seats_available'].append(bus.find_element(By.XPATH, ".//div[@class='seat-left m-top-16']").text[0:2])
            except:
                state_dict['Seats_available'].append(0)

    # Ensure all lists in the dictionary are of the same length
    min_length = min(len(v) for v in state_dict.values())
    for key in state_dict:
        state_dict[key] = state_dict[key][:min_length]

    # Convert the scraped data to a DataFrame
    df = pd.DataFrame(state_dict)

    # Data type conversions
    df['Fare'] = df['Fare'].replace('', np.nan)
    df['Fare'] = pd.to_numeric(df['Fare'], errors='coerce').fillna(0).astype(float)

    # Clean time strings and convert to time format
    df['Departure_time'] = df['Departure_time'].apply(lambda x: x.strip() + ':00' if isinstance(x, str) and len(x.strip()) <= 2 else x)
    df['Arrival_time'] = df['Arrival_time'].apply(lambda x: x.strip() + ':00' if isinstance(x, str) and len(x.strip()) <= 2 else x)

    # Convert to time format
    df['Departure_time'] = pd.to_datetime(df['Departure_time'], format='%H:%M', errors='coerce').dt.time
    df['Arrival_time'] = pd.to_datetime(df['Arrival_time'], format='%H:%M', errors='coerce').dt.time

    # Save the data to a CSV file for the state
    df.to_csv(f'{state_name}_bus_data.csv', index=False)
    print(f"Data saved to {state_name}_bus_data.csv")

# Loop through each state and scrape the bus data
for state_name, state_url in state_link_list.items():
    scrape_state_buses(state_name, state_url)

# Close the browser after scraping all states
driver.quit()
# Out:
# No more pages found for KSRTC (Kerala).
# Number of unique routes for KSRTC (Kerala): 15
# Data saved to KSRTC (Kerala)_bus_data.csv
# No more pages found for APSRTC.
# Number of unique routes for APSRTC: 46
# Data saved to APSRTC_bus_data.csv
# No more pages found for TSRTC.
# Number of unique routes for TSRTC: 26
# Data saved to TSRTC_bus_data.csv
# No more pages found for RSRTC.
# Number of unique routes for RSRTC: 18
# Data saved to RSRTC_bus_data.csv
# No more pages found for PePSU (Punjab).
# Number of unique routes for PePSU (Punjab): 18
# Data saved to PePSU (Punjab)_bus_data.csv
# No more pages found for HRTC.
# Number of unique routes for HRTC: 35
# Data saved to HRTC_bus_data.csv
# No more pages found for WBTC (CTC).
# Number of unique routes for WBTC (CTC): 38
# Data saved to WBTC (CTC)_bus_data.csv
# No more pages found for ASTC.
# Number of unique routes for ASTC: 47
# Data saved to ASTC_bus_data.csv
# No more pages found for KTCL.
# Number of unique routes for KTCL: 34
# Data saved to KTCL_bus_data.csv
# No more pages found for BSRTC.
# Number of unique routes for BSRTC: 39
# Data saved to BSRTC_bus_data.csv

# %% [markdown]
# #### 5. Separating the from_city an₫ to_city from the Route_name

# %%
# Define the folder where your CSV files are stored
csv_folder = r'H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files'

# Function to split route name into "From" and "To" cities
def split_route(route_name):
    if " to " in route_name:
        # Split on " to " to separate From and To
        from_city, to_city = route_name.split(" to ")
        return from_city.strip(), to_city.strip()  # Return cleaned 'From' and 'To' cities
    else:
        return None, None  # If format is incorrect, return None

# Process each CSV file in the folder
for file in os.listdir(csv_folder):
    if file.endswith('.csv'):
        print(f"Processing {file}...")
        
        # Full path to the CSV file
        csv_file = os.path.join(csv_folder, file)
        
        # Load the CSV file into a DataFrame
        df = pd.read_csv(csv_file)
        
        # Ensure 'Route_name' exists in the CSV
        if 'Route_name' in df.columns:
            # Apply the split_route function to split 'Route_name' into 'From' and 'To'
            df['From_City'], df['To_City'] = zip(*df['Route_name'].apply(split_route))
            
            # Save the updated DataFrame back to a new CSV file (or overwrite the existing file)
            output_file = os.path.join(csv_folder, f"01_FAT_{file}")
            df.to_csv(output_file, index=False)
            
            print(f"File saved as {output_file}")

print("All files processed and saved.")
# Out:
# Processing APSRTC_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_APSRTC_bus_data.csv
# Processing ASTC_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_ASTC_bus_data.csv
# Processing BSRTC_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_BSRTC_bus_data.csv
# Processing HRTC_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_HRTC_bus_data.csv
# Processing KSRTC (Kerala)_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_KSRTC (Kerala)_bus_data.csv
# Processing KTCL_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_KTCL_bus_data.csv
# Processing PePSU (Punjab)_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_PePSU (Punjab)_bus_data.csv
# Processing RSRTC_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_RSRTC_bus_data.csv
# Processing TSRTC_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_TSRTC_bus_data.csv
# Processing WBTC (CTC)_bus_data.csv...
# File saved as H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files\01_FAT_WBTC (CTC)_bus_data.csv
# All files processed and saved.

# %% [markdown]
# #### 6.0 Connecting to the MySQL server and creating the database, then adding the data

# %%
# Connect to MySQL
mydb = mysql.connector.connect(
  host = "localhost",
  user = "root",
  password = "Pnu@2024",
  database = "redbus_data"
)

mycursor = mydb.cursor()

# Create the table if it doesn't exist
mycursor.execute("""
CREATE TABLE IF NOT EXISTS redbus_details (
    id INT AUTO_INCREMENT PRIMARY KEY,
    State VARCHAR(255),
    From_City VARCHAR(255),
    To_City VARCHAR(255),
    Route_name VARCHAR(255),
    Bus_name VARCHAR(255),
    Bus_type VARCHAR(255),
    Departure_time TIME,
    Duration VARCHAR(50),
    Arrival_time TIME,
    Ratings DECIMAL(3, 2),
    Fare DECIMAL(10, 2),
    Seat_availability INT,
    Link TEXT
    
);
""")

def insert_into_db(dataframe):
    # Replace NaN values with None
    dataframe = dataframe.where(pd.notnull(dataframe), None)
    
    for index, row in dataframe.iterrows():
        sql = """
        INSERT INTO redbus_details (State, From_City, To_City, Route_name, Bus_name, Bus_type, Departure_time, Duration, Arrival_time, Ratings, Fare, Seat_availability, Link)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        values = (
            row['State'], row['From_City'], row['To_City'], row['Route_name'], row['Bus_name'], row['Bus_type'],
            row['Departure_time'], row['Duration'], row['Arrival_time'], row['Ratings'], row['Fare'], row['Seats_available'], row['Link']
        )

        # Log values before execution for debugging purposes
        print("Inserting values:", values)
        
        # Execute SQL with the provided values
        mycursor.execute(sql, values)
    
    # Commit the transaction after inserting the data
    mydb.commit()

# Specify the folder containing the CSV files
csv_folder = r'H:\01-My Passport\05-Education_Learning\06_Guvi\Data Science\Mini Projects\01_Redbus_Transport\02_final_project\131024_redbus_csv_files'

# Process each CSV file in the folder
for file in os.listdir(csv_folder):
    if file.endswith('.csv'):
        print(f"Processing {file}...")
        csv_file = os.path.join(csv_folder, file)
        df = pd.read_csv(csv_file)

        # Insert the CSV data into MySQL
        insert_into_db(df)

print("Data inserted successfully into MySQL.")

# Close the cursor and database connection
mycursor.close()
mydb.close()
# Out:
# Processing 01_FAT_APSRTC_bus_data.csv...
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'APSRTC - 2674', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '17:30:00', '07h 50m', '01:20:00', 2.6, 436.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Vijayawada', 'Hyderabad', 'Vijayawada to Hyderabad', 'APSRTC - 3366', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '17:55:00', '07h 50m', '01:45:00', 2.4, 436.0, 0, 'https://www.redbus.in/bus-tickets/vijayawada-to-hyderabad')
# Inserting values: ('APSRTC', 'Hyderabad', 'Ongole', 'Hyderabad to Ongole', 'APSRTC - 3360', 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', '18:25:00', '07h 05m', '01:30:00', 2.6, 720.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-ongole')
# Inserting values: ('APSRTC', 'Kakinada', 'Visakhapatnam', 'Kakinada to Visakhapatnam', 'APSRTC - 2575', 'NIGHT RIDER (SEATER CUM SLEEPER)', '18:55:00', '06h 20m', '01:15:00', 4.0, 595.0, 0, 'https://www.redbus.in/bus-tickets/kakinada-to-visakhapatnam')
# Inserting values: ('APSRTC', 'Bangalore', 'Tirupati', 'Bangalore to Tirupati', 'APSRTC - 4916', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '19:25:00', '06h 50m', '02:15:00', 3.4, 469.0, 0, 'https://www.redbus.in/bus-tickets/bangalore-to-tirupathi')
# Inserting values: ('APSRTC', 'Bangalore', 'Kadapa', 'Bangalore to Kadapa', 'APSRTC - 2898', 'STAR LINER(NON-AC SLEEPER 2+1)', '19:25:00', '06h 35m', '02:00:00', 4.7, 607.0, 0, 'https://www.redbus.in/bus-tickets/bangalore-to-kadapa')
# Inserting values: ('APSRTC', 'Ongole', 'Hyderabad', 'Ongole to Hyderabad', 'APSRTC - 2563', 'INDRA(A.C. Seater)', '19:30:00', '05h 55m', '01:25:00', 4.1, 528.0, 0, 'https://www.redbus.in/bus-tickets/ongole-to-hyderabad')
# Inserting values: ('APSRTC', 'Kadapa', 'Bangalore', 'Kadapa to Bangalore', 'APSRTC - 2680', 'VENNELA (A.C. SLEEPER)', '19:45:00', '06h 15m', '02:00:00', 3.2, 839.0, 0, 'https://www.redbus.in/bus-tickets/kadapa-to-bangalore')
# Inserting values: ('APSRTC', 'Chittoor (Andhra Pradesh)', 'Bangalore', 'Chittoor (Andhra Pradesh) to Bangalore', 'APSRTC - 2798', 'INDRA(A.C. Seater)', '19:55:00', '06h 35m', '02:30:00', 4.1, 528.0, 0, 'https://www.redbus.in/bus-tickets/chittoor-andhra-pradesh-to-bangalore')
# Inserting values: ('APSRTC', 'Visakhapatnam', 'Kakinada', 'Visakhapatnam to Kakinada', 'APSRTC - 3622', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '20:00:00', '07h 35m', '03:35:00', 4.5, 444.0, 0, 'https://www.redbus.in/bus-tickets/visakhapatnam-to-kakinada')
# Inserting values: ('APSRTC', 'Bangalore', 'Anantapur (andhra pradesh)', 'Bangalore to Anantapur (andhra pradesh)', 'APSRTC - 2678', 'NIGHT RIDER (SEATER CUM SLEEPER)', '20:00:00', '07h 00m', '03:00:00', 3.6, 639.0, 0, 'https://www.redbus.in/bus-tickets/bangalore-to-ananthapur')
# Inserting values: ('APSRTC', 'Bangalore', 'Chittoor (Andhra Pradesh)', 'Bangalore to Chittoor (Andhra Pradesh)', 'APSRTC - 2688', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '20:00:00', '06h 45m', '02:45:00', 4.4, 469.0, 0, 'https://www.redbus.in/bus-tickets/bangalore-to-chittoor-andhra-pradesh')
# Inserting values: ('APSRTC', 'Anantapur (andhra pradesh)', 'Bangalore', 'Anantapur (andhra pradesh) to Bangalore', 'APSRTC - 4972', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '20:10:00', '07h 10m', '03:20:00', 4.2, 469.0, 0, 'https://www.redbus.in/bus-tickets/ananthapur-to-bangalore')
# Inserting values: ('APSRTC', 'Hyderabad', 'Kurnool', 'Hyderabad to Kurnool', 'APSRTC - 2549', 'NIGHT RIDER (SEATER CUM SLEEPER)', '20:15:00', '06h 00m', '02:15:00', 3.3, 595.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-kurnool')
# Inserting values: ('APSRTC', 'Tirupati', 'Bangalore', 'Tirupati to Bangalore', 'APSRTC - 2573', 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', '20:25:00', '06h 05m', '02:30:00', 3.4, 720.0, 0, 'https://www.redbus.in/bus-tickets/tirupathi-to-bangalore')
# Inserting values: ('APSRTC', 'Narasaraopet', 'Hyderabad', 'Narasaraopet to Hyderabad', 'APSRTC - 4894', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '20:25:00', '06h 35m', '03:00:00', 4.8, 469.0, 0, 'https://www.redbus.in/bus-tickets/narsaraopet-to-hyderabad')
# Inserting values: ('APSRTC', 'Vinukonda', 'Hyderabad', 'Vinukonda to Hyderabad', 'APSRTC - 4896', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '20:30:00', '07h 00m', '03:30:00', 2.2, 436.0, 0, 'https://www.redbus.in/bus-tickets/vinukonda-to-hyderabad')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vinukonda', 'Hyderabad to Vinukonda', 'APSRTC - 4898', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '20:35:00', '06h 25m', '03:00:00', 3.8, 436.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vinukonda')
# Inserting values: ('APSRTC', 'Visakhapatnam', 'Vijayawada', 'Visakhapatnam to Vijayawada', 'APSRTC - 2786', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '20:40:00', '07h 05m', '03:45:00', 3.7, 436.0, 0, 'https://www.redbus.in/bus-tickets/visakhapatnam-to-vijayawada')
# Inserting values: ('APSRTC', 'Bangalore', 'Rayachoti', 'Bangalore to Rayachoti', 'APSRTC - 4880', 'STAR LINER(NON-AC SLEEPER 2+1)', '20:40:00', '06h 05m', '02:45:00', 5.0, 607.0, 0, 'https://www.redbus.in/bus-tickets/bangalore-to-rayachoti')
# Inserting values: ('APSRTC', 'Hyderabad', 'Guntur (Andhra Pradesh)', 'Hyderabad to Guntur (Andhra Pradesh)', 'APSRTC - 35212', 'STAR LINER(NON-AC SLEEPER 2+1)', '20:45:00', '07h 00m', '03:45:00', 5.0, 607.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-guntur')
# Inserting values: ('APSRTC', 'Guntur (Andhra Pradesh)', 'Hyderabad', 'Guntur (Andhra Pradesh) to Hyderabad', 'APSRTC - 3697', 'STAR LINER(NON-AC SLEEPER 2+1)', '20:45:00', '07h 00m', '03:45:00', 4.4, 607.0, 0, 'https://www.redbus.in/bus-tickets/guntur-to-hyderabad')
# Inserting values: ('APSRTC', 'Hyderabad', 'Eluru', 'Hyderabad to Eluru', 'APSRTC - 4920', 'INDRA(A.C. Seater)', '21:00:00', '07h 00m', '04:00:00', 3.7, 528.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-eluru')
# Inserting values: ('APSRTC', 'Eluru', 'Hyderabad', 'Eluru to Hyderabad', 'APSRTC - 38202', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:00:00', '07h 15m', '04:15:00', 3.5, 444.0, 0, 'https://www.redbus.in/bus-tickets/eluru-to-hyderabad')
# Inserting values: ('APSRTC', 'Bangalore', 'Kadiri', 'Bangalore to Kadiri', 'APSRTC - 3544', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:00:00', '06h 40m', '03:40:00', 4.2, 446.0, 0, 'https://www.redbus.in/bus-tickets/bangalore-to-kadiri')
# Inserting values: ('APSRTC', 'Madanapalli', 'Bangalore', 'Madanapalli to Bangalore', 'APSRTC - 3977', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:00:00', '07h 15m', '04:15:00', 3.7, 469.0, 0, 'https://www.redbus.in/bus-tickets/madanapalli-to-bangalore')
# Inserting values: ('APSRTC', 'Bangalore', 'Madanapalli', 'Bangalore to Madanapalli', 'APSRTC - 37801', 'INDRA(A.C. Seater)', '21:00:00', '06h 45m', '03:45:00', 2.8, 567.0, 0, 'https://www.redbus.in/bus-tickets/bangalore-to-madanapalli')
# Inserting values: ('APSRTC', 'Macherla (andhra pradesh)', 'Hyderabad', 'Macherla (andhra pradesh) to Hyderabad', 'APSRTC - 2676', 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', '21:00:00', '07h 00m', '04:00:00', 4.8, 720.0, 0, 'https://www.redbus.in/bus-tickets/macherla-to-hyderabad')
# Inserting values: ('APSRTC', 'Rajahmundry', 'Visakhapatnam', 'Rajahmundry to Visakhapatnam', 'APSRTC - 4351', 'STAR LINER(NON-AC SLEEPER 2+1)', '21:00:00', '07h 00m', '04:00:00', 3.9, 565.0, 0, 'https://www.redbus.in/bus-tickets/rajahmundry-to-visakhapatnam')
# Inserting values: ('APSRTC', 'Nandyal', 'Hyderabad', 'Nandyal to Hyderabad', 'APSRTC - 3612', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:00:00', '07h 10m', '04:10:00', 4.0, 446.0, 0, 'https://www.redbus.in/bus-tickets/nandyala-to-hyderabad')
# Inserting values: ('APSRTC', 'Rayachoti', 'Bangalore', 'Rayachoti to Bangalore', 'APSRTC - 2876', 'STAR LINER(NON-AC SLEEPER 2+1)', '21:00:00', '06h 30m', '03:30:00', 4.2, 607.0, 0, 'https://www.redbus.in/bus-tickets/rayachoti-to-bangalore')
# Inserting values: ('APSRTC', 'Kurnool', 'Hyderabad', 'Kurnool to Hyderabad', 'APSRTC - 4179', 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', '21:05:00', '06h 55m', '04:00:00', 4.0, 670.0, 0, 'https://www.redbus.in/bus-tickets/kurnool-to-hyderabad')
# Inserting values: ('APSRTC', 'Kadiri', 'Bangalore', 'Kadiri to Bangalore', 'APSRTC - 4900', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:15:00', '07h 25m', '04:40:00', 3.6, 436.0, 0, 'https://www.redbus.in/bus-tickets/kadiri-to-bangalore')
# Inserting values: ('APSRTC', 'Visakhapatnam', 'Rajahmundry', 'Visakhapatnam to Rajahmundry', 'APSRTC - 95703', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:25:00', '06h 05m', '03:30:00', 3.3, 452.0, 0, 'https://www.redbus.in/bus-tickets/visakhapatnam-to-rajahmundry')
# Inserting values: ('APSRTC', 'Hyderabad', 'Addanki', 'Hyderabad to Addanki', 'APSRTC - 3962', 'INDRA(A.C. Seater)', '21:25:00', '06h 50m', '04:15:00', 3.6, 567.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-addanki')
# Inserting values: ('APSRTC', 'Hyderabad', 'Anantapur (andhra pradesh)', 'Hyderabad to Anantapur (andhra pradesh)', 'APSRTC - 3911', 'INDRA(A.C. Seater)', '21:30:00', '06h 15m', '03:45:00', 4.0, 528.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-ananthapur')
# Inserting values: ('APSRTC', 'Hyderabad', 'Markapuram', 'Hyderabad to Markapuram', 'APSRTC - 9652', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:30:00', '06h 35m', '04:05:00', 3.1, 444.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-markapuram')
# Inserting values: ('APSRTC', 'Rajahmundry', 'Vijayawada', 'Rajahmundry to Vijayawada', 'APSRTC - 3944', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:30:00', '07h 15m', '04:45:00', 3.7, 469.0, 0, 'https://www.redbus.in/bus-tickets/rajahmundry-to-vijayawada')
# Inserting values: ('APSRTC', 'Tirupati', 'Chennai', 'Tirupati to Chennai', 'APSRTC - 4795', 'INDRA(A.C. Seater)', '21:30:00', '06h 30m', '04:00:00', 3.1, 581.0, 0, 'https://www.redbus.in/bus-tickets/tirupathi-to-chennai')
# Inserting values: ('APSRTC', 'Vijayawada', 'Visakhapatnam', 'Vijayawada to Visakhapatnam', 'APSRTC - 4353', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:35:00', '06h 40m', '04:15:00', 2.0, 469.0, 0, 'https://www.redbus.in/bus-tickets/vijayawada-to-visakhapatnam')
# Inserting values: ('APSRTC', 'Hyderabad', 'Macherla (andhra pradesh)', 'Hyderabad to Macherla (andhra pradesh)', 'APSRTC - 3883', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:35:00', '06h 30m', '04:05:00', 3.4, 444.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-macherla')
# Inserting values: ('APSRTC', 'Hyderabad', 'Rajahmundry', 'Hyderabad to Rajahmundry', 'APSRTC - 4823', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:35:00', '06h 10m', '03:45:00', 4.5, 469.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-rajahmundry')
# Inserting values: ('APSRTC', 'Chilakaluripet', 'Hyderabad', 'Chilakaluripet to Hyderabad', 'APSRTC - 35064', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:38:00', '06h 27m', '04:05:00', 4.5, 444.0, 0, 'https://www.redbus.in/bus-tickets/chilakaluripet-to-hyderabad')
# Inserting values: ('APSRTC', 'Rajahmundry', 'Hyderabad', 'Rajahmundry to Hyderabad', 'APSRTC - 4815', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:45:00', '06h 30m', '04:15:00', 4.6, 469.0, 0, 'https://www.redbus.in/bus-tickets/rajahmundry-to-hyderabad')
# Inserting values: ('APSRTC', 'Kurnool', 'Bangalore', 'Kurnool to Bangalore', 'APSRTC - 4936', 'STAR LINER(NON-AC SLEEPER 2+1)', '21:45:00', '06h 00m', '03:45:00', 2.9, 607.0, 0, 'https://www.redbus.in/bus-tickets/kurnool-to-bangalore')
# Inserting values: ('APSRTC', 'Hyderabad', 'Nandyal', 'Hyderabad to Nandyal', 'APSRTC - 4996', 'INDRA(A.C. Seater)', '21:55:00', '06h 20m', '04:15:00', 4.2, 567.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-nandyala')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'APSRTC - 9655', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '21:55:00', '07h 10m', '05:05:00', 3.5, 444.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'APSRTC - 35136', 'INDRA(A.C. Seater)', '21:58:00', '06h 02m', '04:00:00', 3.9, 539.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'APSRTC - 3570', 'AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)', '22:00:00', '05h 49m', '03:49:00', 3.9, 683.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'APSRTC - 3618', 'SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)', '22:00:00', '07h 30m', '05:30:00', 4.5, 469.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'APSRTC -
0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Sri Durga Malleswari Travels', 'A/C Sleeper (2+1)', '23:10:00', '05h 25m', '04:35:00', 4.2, 800.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '23:05:00', '06h 15m', '05:20:00', 4.3, 459.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Tirumala Xpress', 'A/C Sleeper (2+1)', '23:00:00', '06h 50m', '05:50:00', 3.9, 590.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '22:45:00', '07h 05m', '05:50:00', 3.9, 609.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Yolo Bus', 'A/C Seater / Sleeper (2+1)', '22:46:00', '06h 38m', '05:24:00', 3.9, 450.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'NueGo', 'Electric A/C Seater (2+2)', '22:30:00', '07h 05m', '05:35:00', 3.8, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'V Kaveri Travels', 'A/C Sleeper (2+1)', '23:00:00', '05h 15m', '04:15:00', 4.0, 700.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'LVR Travels', 'Non A/C Seater / Sleeper (2+1)', '23:37:00', '06h 08m', '05:45:00', 3.9, 669.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Sri KVR Travels', 'NON A/C Sleeper (2+1)', '23:01:00', '06h 30m', '05:31:00', 3.9, 560.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Zingbus Plus', 'A/C Seater / Sleeper (2+1)', '23:03:00', '06h 27m', '05:30:00', 5.0, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'NueGo', 'Electric A/C Seater (2+2)', '22:00:00', '07h 20m', '05:20:00', 3.9, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Go Tour Travels and Holidays', 'A/C Seater / Sleeper (2+1)', '22:48:00', '05h 27m', '04:15:00', 4.5, 1190.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'LVP Travels', 'A/C Seater / Sleeper (2+1)', '22:19:00', '06h 26m', '04:45:00', 3.8, 680.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'A/C Sleeper (2+1)', '22:25:00', '06h 20m', '04:45:00', 3.6, 800.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'NON A/C Seater/ Sleeper (2+1)', '23:00:00', '06h 30m', '05:30:00', 3.4, 700.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'NON A/C Seater/ Sleeper (2+1)', '23:00:00', '06h 45m', '05:45:00', 3.3, 800.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'CVR Express', 'Non A/C Seater / Sleeper (2+1)', '21:40:00', '06h 20m', '04:00:00', 3.7, 670.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'IntrCity SmartBus', 'A/C Seater / Sleeper (2+1)', '19:05:00', '07h 55m', '03:00:00', 4.8, 869.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Sri Venkata Padmavathi Travels', 'Non A/C Seater / Sleeper (2+1)', '22:42:00', '07h 18m', '06:00:00', 3.6, 550.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Nani Svkdt Travels', 'A/C Sleeper (2+1)', '22:00:00', '06h 20m', '04:20:00', 3.7, 870.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Kaveri Travels', 'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)', '21:30:00', '06h 00m', '03:30:00', 3.9, 880.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'Bharat Benz A/C Sleeper (2+1)', '22:55:00', '06h 50m', '05:45:00', 3.1, 800.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Morning Star Travels', 'A/C Sleeper (2+1)', '23:05:00', '06h 15m', '05:20:00', 3.3, 690.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'Bharat Benz A/C Sleeper (2+1)', '22:55:00', '06h 50m', '05:45:00', 3.1, 1000.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '20:40:00', '06h 50m', '03:30:00', 5.0, 889.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'IntrCity SmartBus', 'VE A/C Seater / Sleeper (2+1)', '18:15:00', '07h 55m', '02:10:00', 4.7, 679.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'V Kaveri Travels', 'Non A/C Seater / Sleeper (2+1)', '22:22:00', '06h 08m', '04:30:00', 3.5, 780.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Nani Svkdt Travels', 'A/C Sleeper (2+1)', '23:20:00', '05h 10m', '04:30:00', 3.7, 870.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '19:15:00', '05h 05m', '00:20:00', 4.8, 929.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'NON A/C Seater/ Sleeper (2+1)', '23:00:00', '06h 30m', '05:30:00', 3.3, 800.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'Bharat Benz A/C Sleeper (2+1)', '22:55:00', '06h 20m', '05:15:00', 3.0, 800.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Kaveri Travels', 'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)', '21:30:00', '07h 00m', '04:30:00', 4.1, 900.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Holidays Tours and Travels', 'A/C Seater / Sleeper (2+1)', '22:40:00', '05h 44m', '04:24:00', 4.8, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'V Kaveri Travels', 'A/C Seater / Sleeper (2+1)', '23:00:00', '06h 10m', '05:10:00', 3.5, 600.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Sri Sai Srinivasa Travels', 'Non A/C Seater / Sleeper (2+1)', '22:10:00', '06h 20m', '04:30:00', 3.7, 680.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'SVR Tours and Travels', 'Volvo Multi Axle Sleeper B11R (2+1)', '17:15:00', '06h 35m', '23:50:00', 3.2, 800.0, 24, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'KPS Buses', 'A/C Sleeper (2+1)', '21:15:00', '07h 15m', '04:30:00', 0.0, 3000.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Zingbus Plus', 'A/C Sleeper (2+1)', '17:30:00', '07h 20m', '00:50:00', 4.5, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'DSM TRAVELS', 'A/C Seater / Sleeper (2+1)', '21:40:00', '06h 30m', '04:10:00', 0.0, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'KPS Buses', 'A/C Sleeper (2+1)', '21:05:00', '07h 25m', '04:30:00', 0.0, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Amigos Travels', 'A/C Sleeper (2+1)', '22:10:00', '06h 20m', '04:30:00', 0.0, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'SREE CHAKRA TRAVELS', 'Non A/C Seater / Sleeper (2+1)', '22:30:00', '05h 30m', '04:00:00', 0.0, 5000.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Sri Siddi Ganapathi Travels', 'A/C Seater / Sleeper (2+1)', '21:30:00', '07h 00m', '04:30:00', 0.0, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'LG Travels', 'A/C Seater / Sleeper (2+1)', '21:15:00', '05h 35m', '02:50:00', 0.0, 6500.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Sudha Sri Tours and Travels', 'A/C Sleeper (2+1)', '22:55:00', '05h 05m', '04:00:00', 3.3, 590.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'SAMANVI CITICONNECT', 'A/C Sleeper (2+1)', '21:54:00', '06h 26m', '04:20:00', 2.9, 899.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'Volvo 9600 Multi-Axle A/C Sleeper (2+1)', '16:30:00', '04h 30m', '21:00:00', 3.6, 900.0, 12, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'Bharat Benz A/C Seater /Sleeper (2+1)', '22:55:00', '06h 50m', '05:45:00', 2.5, 500.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'V Kaveri Travels', 'Non A/C Seater / Sleeper (2+1)', '22:25:00', '06h 05m', '04:30:00', 3.8, 1000.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Go Tour Travels and Holidays', 'A/C Sleeper (2+1)', '22:48:00', '05h 27m', '04:15:00', 3.7, 990.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Ramana Tours And Travels', 'A/C Sleeper (2+1)', '18:00:00', '07h 05m', '01:05:00', 3.4, 0.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'NON A/C Seater/ Sleeper (2+1)', '19:45:00', '08h 10m', '03:55:00', 2.7, 700.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Orange Tours And Travels', 'NON A/C Sleeper (2+1)', '22:55:00', '06h 50m', '05:45:00', 2.9, 700.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# Inserting values: ('APSRTC', 'Hyderabad', 'Vijayawada', 'Hyderabad to Vijayawada', 'Yolo Bus', 'Bharat Benz A/C Sleeper (2+1)', '19:40:00', '06h 49m', '02:29:00', 4.6, 1040.0, 0, 'https://www.redbus.in/bus-tickets/hyderabad-to-vijayawada')
# ...
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'Snemita Parisheba', 'AC Seater (2+3)', '13:15:00', '04h 45m', '18:00:00', 1.9, 470, 22, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-BELDA - ASANSOL - VIA - KOLKATA - 06:00 (ASN DEPOT - 3990', 'Non AC Seater (2+3)', '10:45:00', '04h 15m', '15:00:00', 3.7, 150, 52, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-KOLKATA - PURULIA - VIA - ASN - 11:00 (HWH DEPOT) - 2681', 'Non AC Seater (2+3)', '11:00:00', '03h 30m', '14:30:00', 1.9, 150, 52, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-KOLKATA - DURGAPUR - L/S - 11:20 (DGP DEPOT) - 758', 'Non AC Seater (2+3)', '11:20:00', '03h 30m', '14:50:00', 4.9, 150, 49, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-KARUNAMOYEE - DURGAPUR - 11:30 (DGP DEPOT) - 178', 'Non AC Seater (2+3)', '11:30:00', '03h 45m', '15:15:00', 3.3, 155, 48, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-KARUNAMOYEE - BANKURA - VIA - DURGAPUR - 12:00 - 310', 'Non AC Seater (2+3)', '12:00:00', '03h 45m', '15:45:00', 2.7, 155, 50, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-KOLKATA - PURULIA - VIA - BANKURA - 12:00 (HWH DEP - 401', 'Non AC Seater (2+3)', '12:00:00', '03h 30m', '15:30:00', 5.0, 155, 51, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-KOLKATA - ASANSOL - L/S - 12:30 (ASANSOL DEPOT) - 252', 'Non AC Seater (2+3)', '12:30:00', '03h 30m', '16:00:00', 2.1, 150, 52, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-KOLKATA - DURGAPUR - 12:50 (Durgapur) - 328', 'Non AC Seater (2+3)', '12:50:00', '03h 30m', '16:20:00', 3.6, 150, 52, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Purulia', 'Kolkata to Purulia', 'SBSTC-KOLKATA - PURULIA - VIA - BANKURA - 13:00 (PRL DEP - 290', 'Non AC Seater (2+3)', '13:00:00', '03h 00m', '16:00:00', 3.6, 150, 51, 'https://www.redbus.in/bus-tickets/kolkata-to-purulia')
# Inserting values: ('WBTC (CTC)', 'Kolkata', 'Suri', 'Kolkata to Suri', 